# %%
import pandas as pd
data = pd.read_csv("train_ads_minimal_label1.csv")  #119136 x 17
print(data.shape)
# Out:
# (119136, 17)

# %%
pip install be-great
# Out:
# Collecting be-great
#   Downloading be_great-0.0.8-py3-none-any.whl.metadata (5.7 kB)
# Collecting datasets>=2.5.2 (from be-great)
#   Downloading datasets-3.3.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.1 in /usr/local/lib/python3.11/dist-packages (from be-great) (1.26.4)
# Requirement already satisfied: pandas>=1.4.4 in /usr/local/lib/python3.11/dist-packages (from be-great) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from be-great) (1.6.1)
# Requirement already satisfied: torch>=1.10.2 in /usr/local/lib/python3.11/dist-packages (from be-great) (2.5.1+cu124)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.11/dist-packages (from be-great) (4.67.1)
# Requirement already satisfied: transformers>=4.22.1 in /usr/local/lib/python3.11/dist-packages (from be-great) (4.48.3)
# Requirement already satisfied: accelerate>=0.20.1 in /usr/local/lib/python3.11/dist-packages (from be-great) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.20.1->be-great) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.20.1->be-great) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.20.1->be-great) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.20.1->be-great) (0.28.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.20.1->be-great) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.5.2->be-great) (3.17.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.5.2->be-great) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.5.2->be-great)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.5.2->be-great) (2.32.3)
# Collecting xxhash (from datasets>=2.5.2->be-great)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.5.2->be-great)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=2.5.2->be-great) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.5.2->be-great) (3.11.13)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.4->be-great) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.4->be-great) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.4->be-great) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.1->be-great) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.1->be-great) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.1->be-great) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.2->be-great) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.2->be-great) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.2->be-great) (3.1.5)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.10.2->be-great)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.10.2->be-great)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.10.2->be-great)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.10.2->be-great)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.10.2->be-great)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.10.2->be-great)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.10.2->be-great)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.10.2->be-great)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.10.2->be-great)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.2->be-great) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.2->be-great) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.10.2->be-great)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.2->be-great) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.2->be-great) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.10.2->be-great) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.1->be-great) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.22.1->be-great) (0.21.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.5.2->be-great) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.5.2->be-great) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.5.2->be-great) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.5.2->be-great) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.5.2->be-great) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.5.2->be-great) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.5.2->be-great) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.4->be-great) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.5.2->be-great) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.5.2->be-great) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.5.2->be-great) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.5.2->be-great) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.10.2->be-great) (3.0.2)
# Downloading be_great-0.0.8-py3-none-any.whl (16 kB)
# Downloading datasets-3.3.2-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 15.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 19.8 MB/s eta 0:00:00
# Installing collected packages: xxhash, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, be-great
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed be-great-0.0.8 datasets-3.3.2 dill-0.3.8 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 xxhash-3.5.0

# %%
from be_great import GReaT
import pandas as pd
# Initialize the GReaT model
# Using distilgpt2 which has a context window of ~1024 tokens.
#model = GReaT(llm='distilgpt2', batch_size=64, epochs=2, save_steps=400000)
model = GReaT(llm='gpt2', batch_size=64, epochs=2, save_steps=400000)

# Train the model on your dataset
model.fit(data)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/be_great/great.py:165: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `GReaTTrainer.__init__`. Use `processing_class` instead.
#   great_trainer = GReaTTrainer(
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: hengyuanliu to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/content/wandb/run-20250306_034147-labkey2j</code>
# Syncing run <strong><a href='https://wandb.ai/hengyuanliu/huggingface/runs/labkey2j' target="_blank">trainer_great</a></strong> to <a href='https://wandb.ai/hengyuanliu/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/hengyuanliu/huggingface' target="_blank">https://wandb.ai/hengyuanliu/huggingface</a>
#  View run at <a href='https://wandb.ai/hengyuanliu/huggingface/runs/labkey2j' target="_blank">https://wandb.ai/hengyuanliu/huggingface/runs/labkey2j</a>
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='3724' max='3724' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3724/3724 57:43, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.627800</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.497500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.478000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.467500</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.462500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.459200</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.457300</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
model.save("GReaT_model_GPT2")

# %%
model = GReaT.load_from_dir("GReaT_model_GPT2")  # loads the model again

# %%
# Define total number of synthetic samples and the batch size for generation
total_samples = 119136 #119136
batch_size_gen = 1000  # Adjust this based on your available memory and resources
all_synthetic = {}
# Generate synthetic data in batches
num_batches = total_samples // batch_size_gen  # Should be 2 in this case

# Generate synthetic data in batches using a max_length that fits the model's context window
for i in range(0, total_samples, batch_size_gen):
    start = i * batch_size_gen
    end = start + batch_size_gen
    print(f"Generating samples {i} to {i + batch_size_gen}...")
    batch = model.sample(max_length=1024, n_samples=batch_size_gen)
    # Store the batch DataFrame in the dictionary with a unique key
    batch_df = pd.DataFrame(batch)
    all_synthetic[f"batch_{i + 1}"] = batch_df
# Out:
# Generating samples 0 to 1000...
#   0%|          | 0/1000 [00:00<?, ?it/s]The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# 1086it [00:17, 61.08it/s]
# Generating samples 1000 to 2000...
# 1084it [00:17, 63.30it/s]
# Generating samples 2000 to 3000...
# 1086it [00:16, 64.40it/s]
# Generating samples 3000 to 4000...
# 1090it [00:17, 63.85it/s]
# Generating samples 4000 to 5000...
# 1087it [00:17, 63.83it/s]
# Generating samples 5000 to 6000...
# 1082it [00:16, 63.77it/s]
# Generating samples 6000 to 7000...
# 1088it [00:16, 65.33it/s]
# Generating samples 7000 to 8000...
# 1088it [00:16, 64.33it/s]
# Generating samples 8000 to 9000...
# 1086it [00:17, 63.65it/s]
# Generating samples 9000 to 10000...
# 1087it [00:16, 64.15it/s]
# Generating samples 10000 to 11000...
# 1079it [00:17, 61.81it/s]
# Generating samples 11000 to 12000...
# 1079it [00:17, 61.92it/s]
# Generating samples 12000 to 13000...
# 1089it [00:17, 63.38it/s]
# Generating samples 13000 to 14000...
# 1087it [00:16, 65.37it/s]
# Generating samples 14000 to 15000...
# 1086it [00:16, 63.92it/s]
# Generating samples 15000 to 16000...
# 1084it [00:17, 63.54it/s]
# Generating samples 16000 to 17000...
# 1087it [00:17, 63.90it/s]
# Generating samples 17000 to 18000...
# 1081it [00:17, 62.00it/s]
# Generating samples 18000 to 19000...
# 1082it [00:17, 62.76it/s]
# Generating samples 19000 to 20000...
# 1083it [00:17, 62.09it/s]
# Generating samples 20000 to 21000...
# 1089it [00:17, 63.81it/s]
# Generating samples 21000 to 22000...
# 1089it [00:17, 61.81it/s]
# Generating samples 22000 to 23000...
# 1087it [00:17, 63.55it/s]
# Generating samples 23000 to 24000...
# 1087it [00:17, 62.74it/s]
# Generating samples 24000 to 25000...
# 1082it [00:16, 63.91it/s]
# Generating samples 25000 to 26000...
# 1089it [00:17, 62.01it/s]
# Generating samples 26000 to 27000...
# 1084it [00:17, 63.51it/s]
# Generating samples 27000 to 28000...
# 1088it [00:16, 64.86it/s]
# Generating samples 28000 to 29000...
# 1082it [00:17, 61.90it/s]
# Generating samples 29000 to 30000...
# 1087it [00:17, 63.42it/s]
# Generating samples 30000 to 31000...
# 1087it [00:16, 64.26it/s]
# Generating samples 31000 to 32000...
# 1086it [00:17, 63.03it/s]
# Generating samples 32000 to 33000...
# 1085it [00:17, 63.82it/s]
# Generating samples 33000 to 34000...
# 1082it [00:17, 63.01it/s]
# Generating samples 34000 to 35000...
# 1085it [00:16, 63.93it/s]
# Generating samples 35000 to 36000...
# 1092it [00:16, 64.32it/s]
# Generating samples 36000 to 37000...
# 1085it [00:17, 62.40it/s]
# Generating samples 37000 to 38000...
# 1082it [00:17, 62.70it/s]
# Generating samples 38000 to 39000...
# 1083it [00:17, 62.28it/s]
# Generating samples 39000 to 40000...
# 1082it [00:17, 63.15it/s]
# Generating samples 40000 to 41000...
# 1086it [00:17, 63.24it/s]
# Generating samples 41000 to 42000...
# 1085it [00:16, 64.64it/s]
# Generating samples 42000 to 43000...
# 1085it [00:16, 63.86it/s]
# Generating samples 43000 to 44000...
# 1085it [00:17, 62.93it/s]
# Generating samples 44000 to 45000...
# 1085it [00:16, 64.35it/s]
# Generating samples 45000 to 46000...
# 1081it [00:17, 63.29it/s]
# Generating samples 46000 to 47000...
# 1080it [00:17, 63.13it/s]
# Generating samples 47000 to 48000...
# 1083it [00:17, 62.73it/s]
# Generating samples 48000 to 49000...
# 1094it [00:16, 64.97it/s]
# Generating samples 49000 to 50000...
# 1085it [00:17, 63.66it/s]
# Generating samples 50000 to 51000...
# 1087it [00:17, 62.47it/s]
# Generating samples 51000 to 52000...
# 1082it [00:16, 64.92it/s]
# Generating samples 52000 to 53000...
# 1092it [00:16, 64.97it/s]
# Generating samples 53000 to 54000...
# 1092it [00:17, 63.29it/s]
# Generating samples 54000 to 55000...
# 1090it [00:17, 63.67it/s]
# Generating samples 55000 to 56000...
# 1085it [00:17, 62.91it/s]
# Generating samples 56000 to 57000...
# 1090it [00:17, 63.68it/s]
# Generating samples 57000 to 58000...
# 1092it [00:16, 64.31it/s]
# Generating samples 58000 to 59000...
# 1087it [00:17, 63.21it/s]
# Generating samples 59000 to 60000...
# 1081it [00:17, 63.00it/s]
# Generating samples 60000 to 61000...
# 1083it [00:17, 63.06it/s]
# Generating samples 61000 to 62000...
# 1087it [00:16, 64.74it/s]
# Generating samples 62000 to 63000...
# 1087it [00:17, 62.86it/s]
# Generating samples 63000 to 64000...
# 1086it [00:16, 64.99it/s]
# Generating samples 64000 to 65000...
# 1086it [00:16, 64.63it/s]
# Generating samples 65000 to 66000...
# 1080it [00:17, 62.99it/s]
# Generating samples 66000 to 67000...
# 1082it [00:17, 62.46it/s]
# Generating samples 67000 to 68000...
# 1083it [00:16, 64.08it/s]
# Generating samples 68000 to 69000...
# 1081it [00:16, 63.61it/s]
# Generating samples 69000 to 70000...
# 1094it [00:17, 64.22it/s]
# Generating samples 70000 to 71000...
# 1091it [00:17, 62.86it/s]
# Generating samples 71000 to 72000...
# 1084it [00:17, 63.00it/s]
# Generating samples 72000 to 73000...
# 1086it [00:16, 64.58it/s]
# Generating samples 73000 to 74000...
# 1086it [00:17, 62.86it/s]
# Generating samples 74000 to 75000...
# 1085it [00:17, 63.55it/s]
# Generating samples 75000 to 76000...
# 1088it [00:16, 64.69it/s]
# Generating samples 76000 to 77000...
# 1076it [00:17, 62.32it/s]
# Generating samples 77000 to 78000...
# 1081it [00:17, 63.54it/s]
# Generating samples 78000 to 79000...
# 1090it [00:16, 64.28it/s]
# Generating samples 79000 to 80000...
# 1090it [00:16, 65.13it/s]
# Generating samples 80000 to 81000...
# 1086it [00:16, 64.78it/s]
# Generating samples 81000 to 82000...
# 1085it [00:17, 63.70it/s]
# Generating samples 82000 to 83000...
# 1093it [00:17, 63.95it/s]
# Generating samples 83000 to 84000...
# 1086it [00:17, 61.43it/s]
# Generating samples 84000 to 85000...
# 1084it [00:17, 63.62it/s]
# Generating samples 85000 to 86000...
# 1082it [00:16, 64.16it/s]
# Generating samples 86000 to 87000...
# 1083it [00:17, 63.68it/s]
# Generating samples 87000 to 88000...
# 1087it [00:16, 63.96it/s]
# Generating samples 88000 to 89000...
# 1088it [00:17, 63.69it/s]
# Generating samples 89000 to 90000...
# 1085it [00:17, 63.40it/s]
# Generating samples 90000 to 91000...
# 1086it [00:17, 62.58it/s]
# Generating samples 91000 to 92000...
# 1085it [00:17, 63.62it/s]
# Generating samples 92000 to 93000...
# 1087it [00:17, 63.12it/s]
# Generating samples 93000 to 94000...
# 1083it [00:17, 63.34it/s]
# Generating samples 94000 to 95000...
# 1086it [00:17, 63.03it/s]
# Generating samples 95000 to 96000...
# 1082it [00:17, 62.82it/s]
# Generating samples 96000 to 97000...
# 1082it [00:17, 62.20it/s]
# Generating samples 97000 to 98000...
# 1087it [00:16, 64.09it/s]
# Generating samples 98000 to 99000...
# 1092it [00:17, 62.68it/s]
# Generating samples 99000 to 100000...
# 1085it [00:17, 62.31it/s]
# Generating samples 100000 to 101000...
# 1091it [00:17, 64.08it/s]
# Generating samples 101000 to 102000...
# 1081it [00:16, 64.19it/s]
# Generating samples 102000 to 103000...
# 1087it [00:17, 62.78it/s]
# Generating samples 103000 to 104000...
# 1091it [00:17, 63.48it/s]
# Generating samples 104000 to 105000...
# 1086it [00:16, 63.99it/s]
# Generating samples 105000 to 106000...
# 1090it [00:17, 62.62it/s]
# Generating samples 106000 to 107000...
# 1084it [00:17, 63.45it/s]
# Generating samples 107000 to 108000...
# 1082it [00:17, 63.12it/s]
# Generating samples 108000 to 109000...
# 1081it [00:16, 64.55it/s]
# Generating samples 109000 to 110000...
# 1087it [00:17, 63.72it/s]
# Generating samples 110000 to 111000...
# 1092it [00:17, 63.74it/s]
# Generating samples 111000 to 112000...
# 1086it [00:17, 62.83it/s]
# Generating samples 112000 to 113000...
# 1088it [00:16, 64.78it/s]
# Generating samples 113000 to 114000...
# 1082it [00:17, 63.52it/s]
# Generating samples 114000 to 115000...
# 1088it [00:17, 63.68it/s]
# Generating samples 115000 to 116000...
# 1090it [00:16, 64.46it/s]
# Generating samples 116000 to 117000...
# 1085it [00:16, 64.63it/s]
# Generating samples 117000 to 118000...
# 1090it [00:16, 64.18it/s]
# Generating samples 118000 to 119000...
# 1079it [00:17, 62.14it/s]
# Generating samples 119000 to 120000...
# 1091it [00:16, 64.60it/s]

# %%
combined_synthetic_df = pd.concat(all_synthetic.values(), ignore_index=True)
print("Combined DataFrame shape:", combined_synthetic_df.shape)
# Out:
# Combined DataFrame shape: (120000, 17)

# %%
combined_synthetic_df.to_csv('synthetic_data_GReaTGPT2.csv', index=False)
